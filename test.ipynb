# %%
import pandas as pd
# Out:
# '.' expected
# import pandaas as pd;
#               ^
# ';' expected
# import pandaas as pd;
#                  ^

# %%
import pandas as pd
# Out:
# '.' expected
# import pandas as pd;
#              ^
# ';' expected
# import pandas as pd;
#                 ^
